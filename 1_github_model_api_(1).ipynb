# %% [markdown]
# <a href="https://colab.research.google.com/github/NikoConK/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/main/1_github_model_api_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Abrir en Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/fvalenzuelag/Ingenier-a-de-Soluciones-con-Inteligencia-Artificial/blob/main/RA1/IL1.1/1-github_model_api.ipynb)

# %% [markdown]
# ## Primera Llamada al Modelo
#
# En este ejercicio, aprenderemos a realizar nuestra primera llamada a un modelo de lenguaje usando la API de **Groq**.
#
# # 1. Conexión Directa con el Cliente OpenAI
#
# ## Objetivos de Aprendizaje
# - Configurar una conexión directa con Groq usando el cliente OpenAI
# - Comprender los parámetros básicos de configuración de API
# - Implementar llamadas básicas a modelos de lenguaje
# - Aplicar mejores prácticas de seguridad con API keys
#
# ## Introducción
# Groq da acceso gratuito a varios modelos de lenguaje mediante una **API compatible con OpenAI**.
# Eso significa que usamos la misma librería `openai` de siempre: solo cambiamos el `base_url`.
# En este notebook aprenderemos a:
# 1. Configurar el entorno y las credenciales
# 2. Establecer una conexión con la API
# 3. Realizar llamadas básicas al modelo
# 4. Explorar diferentes parámetros de configuración
#
# ## Configuración de Credenciales
#
# - **En Google Colab:** carga tus keys en el panel 🔑 **Secrets** de la barra lateral
#   (`LLM_API_KEY` y `GOOGLE_API_KEY`) y activa "Notebook access". La celda de abajo las lee sola.
# - **En local:** copia `.env.example` a `.env` en la raíz del repo y complétalo.
#
# Tu key gratuita de Groq se obtiene en [console.groq.com/keys](https://console.groq.com/keys).
#
# **Mejores Prácticas de Seguridad:**
# - Nunca hardcodees API keys en el código
# - Usa los Secrets de Colab o un archivo `.env`
# - No compartas credenciales en repositorios públicos
# - Rota las API keys regularmente

# %%
# --- Instalación de dependencias (se ejecuta solo en Google Colab) ---
# En local no hace nada: usa `pip install -r requirements.txt` desde la raíz del repo.
import sys
if "google.colab" in sys.modules:
    # !pip install -q openai python-dotenv

# %%
# !pip install -q openai

# %%
# !pip install -qU langchain-groq langgraph
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 4.6 MB/s eta 0:00:00

# %%
import os
from google.colab import userdata
from openai import OpenAI

# Recuperar la API Key desde Secrets de Google Colab
api_key = userdata.get("GROQ_API_KEY")

if not api_key:
    raise ValueError(
        "No se encontró LLM_API_KEY. "
        "Agrégala en el panel Secrets de Google Colab."
    )

# Crear el cliente que se conectará con Groq
client = OpenAI(
    api_key=api_key,
    base_url="https://api.groq.com/openai/v1"
)

print("Cliente configurado correctamente")
# Out:
# Cliente configurado correctamente

# %%
import os
from google.colab import userdata
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)

respuesta = llm.invoke(
    "Hola, dime las características del modelo usado (llama-3.3-70b-versatile)"
)

print(respuesta.content)
# Out:
# ¡Hola! Me alegra ayudarte a aprender a freír un huevo de manera sencilla y deliciosa.
#
# **Materiales necesarios:**
#
# * Un huevo fresco
# * Una sartén antiadherente o una sartén de teflón
# * Aceite o mantequilla para freír
# * Sal y pimienta al gusto (opcional)
#
# **Pasos para freír un huevo:**
#
# 1. **Calienta la sartén**: Coloca la sartén a fuego medio y agrega una pequeña cantidad de aceite o mantequilla. Deja que se caliente durante unos minutos hasta que esté caliente y listo para freír.
# 2. **Rompe el huevo**: Rompe el huevo en un tazón o plato pequeño para evitar que se salga de la sartén. Asegúrate de que no haya cascara de huevo en el tazón.
# 3. **Agrega el huevo a la sartén**: Con cuidado, agrega el huevo a la sartén caliente. Deja que se cocine durante unos segundos hasta que la clara del huevo esté transparente y la yema esté líquida.
# 4. **Cocina el huevo**: Cocina el huevo durante 2-3 minutos, o hasta que la clara esté completamente cocida y la yema esté líquida y cremosa. Si deseas un huevo más cocido, puedes cocinarlo durante 4-5 minutos.
# 5. **Voltea el huevo (opcional)**: Si deseas un huevo con la yema volteada, utiliza una espátula para voltear el huevo con cuidado. Cocina durante otros 30 segundos a 1 minuto.
# 6. **Sazona con sal y pimienta**: Agrega sal y pimienta al gusto para darle sabor al huevo.
# 7. **Sirve y disfruta**: Retira el huevo de la sartén y colócalo en un plato. Sirve caliente y disfruta de tu delicioso huevo frito.
#
# **Consejos y variaciones:**
#
# * Utiliza un huevo fresco para obtener un mejor sabor y textura.
# * Ajusta el tiempo de cocción según tus preferencias personales.
# * Agrega ingredientes como cebolla, pimiento, champiñones o espinacas para darle un toque especial al huevo.
# * Utiliza diferentes tipos de aceite o mantequilla para darle un sabor único al huevo.
#
# Espero que esta guía te haya ayudado a aprender a freír un huevo de manera sencilla y deliciosa. ¡Buen provecho!

# %%
import os
from google.colab import userdata
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"] = userdata.get("GROQ_API_KEY")

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0.7
)
#pregunta=input("Ingrese su pregunta")
respuesta = llm.invoke(input("Ingrese su pregunta"))

print(respuesta.content)
# Out:
# Ingrese su preguntaGenera un coódigo en python para sumar dos números
# **Suma de dos números en Python**
# =====================================
#
# Aquí te presento un código simple en Python que suma dos números:
#
# ```python
# def suma_numeros(a, b):
#     """
#     Función que suma dos números.
#
#     Args:
#         a (int): Primer número
#         b (int): Segundo número
#
#     Returns:
#         int: Resultado de la suma
#     """
#     return a + b
#
# # Pedir los números al usuario
# num1 = int(input("Ingrese el primer número: "))
# num2 = int(input("Ingrese el segundo número: "))
#
# # Llamar a la función y mostrar el resultado
# resultado = suma_numeros(num1, num2)
# print("La suma de {} y {} es: {}".format(num1, num2, resultado))
# ```
#
# **Explicación del código:**
#
# 1. Definimos una función llamada `suma_numeros` que toma dos argumentos, `a` y `b`.
# 2. Dentro de la función, simplemente retornamos la suma de `a` y `b` usando el operador `+`.
# 3. Pedimos al usuario que ingrese dos números utilizando la función `input`.
# 4. Convertimos los números ingresados a enteros utilizando la función `int`.
# 5. Llamamos a la función `suma_numeros` con los números ingresados y almacenamos el resultado en la variable `resultado`.
# 6. Mostramos el resultado utilizando la función `print` y la cadena de formato `format`.
#
# **Ejemplo de uso:**
#
# ```
# Ingrese el primer número: 5
# Ingrese el segundo número: 3
# La suma de 5 y 3 es: 8
# ```
#
# Espero que esto te sea útil. ¡Si tienes alguna pregunta o necesitas más ayuda, no dudes en preguntar!

# %%
# @title
# --- Credenciales: funciona en local (.env) y en Google Colab (Secrets) ---
import os
try:
    from google.colab import userdata          # Colab: panel 🔑 Secrets
    # Solo LLM_API_KEY es obligatorio. Los demás son opcionales: defínelos como
    # Secrets únicamente si quieres usar otro proveedor o modelo.
    for _k in ("LLM_API_KEY", "GOOGLE_API_KEY", "LANGSMITH_API_KEY",
               "LLM_BASE_URL", "LLM_MODEL", "LLM_MODEL_SMALL"):
        try:
            os.environ[_k] = userdata.get(_k)
        except Exception:
            pass                                # el Secret no existe: se usa el default
    os.environ.setdefault("LLM_BASE_URL", "https://api.groq.com/openai/v1")
    os.environ.setdefault("LLM_MODEL", "llama-3.3-70b-versatile")
    os.environ.setdefault("LLM_MODEL_SMALL", "llama-3.1-8b-instant")
except ImportError:
    from dotenv import load_dotenv             # Local: archivo .env en la raíz
    load_dotenv()

# Importar las bibliotecas necesarias
from openai import OpenAI
import os

# Verificar que tenemos las bibliotecas correctas
print("OpenAI library version:", __import__('openai').__version__)
print("Python version:", __import__('sys').version)

# Configuración del cliente: la librería `openai` apuntada a Groq
try:
    # Configurar el cliente con variables de entorno
    client = OpenAI(
        base_url=os.environ.get("LLM_BASE_URL"),
        api_key=os.environ.get("LLM_API_KEY")
    )

    # Verificar configuración (sin mostrar la API key completa por seguridad)
    print("Base URL configurada:", client.base_url)
    print("API Key configurada:", "✓" if client.api_key else "✗")

    if client.api_key:
        # NUNCA imprimas la key, ni siquiera un fragmento: el output queda guardado
        # dentro del .ipynb y viaja al repositorio cuando haces commit.
        print(f"API Key cargada correctamente ({len(client.api_key)} caracteres)")
    else:
        print("⚠️  API Key no encontrada. Asegúrate de configurar LLM_API_KEY")

except Exception as e:
    print(f"Error en configuración: {e}")
    print("Verifica que las variables de entorno estén configuradas correctamente")
# Out:
# OpenAI library version: 2.45.0
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# Error en configuración: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
# Verifica que las variables de entorno estén configuradas correctamente

# %%
# Primera llamada básica al modelo
def llamada_basica():
    try:
        response = client.chat.completions.create(
            model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
            messages=[
                {"role": "user", "content": "Hola, ¿cómo estás? Responde en una oración."}
            ],
            temperature=0.1,
            max_tokens=150
        )

        print("=== Respuesta del Modelo ===")
        print(response.choices[0].message.content)
        print("\n=== Información Técnica ===")
        print(f"Modelo usado: {response.model}")
        print(f"Tokens usados: {response.usage.total_tokens}")
        print(f"Tokens de entrada: {response.usage.prompt_tokens}")
        print(f"Tokens de salida: {response.usage.completion_tokens}")

    except Exception as e:
        print(f"Error en la llamada: {e}")
        print("Verifica tu configuración y conexión a internet")

# Ejecutar la función
llamada_basica()
# Out:
# === Respuesta del Modelo ===
# Estoy funcionando correctamente, gracias por preguntar, y estoy listo para ayudarte en lo que necesites.
#
# === Información Técnica ===
# Modelo usado: llama-3.3-70b-versatile
# Tokens usados: 76
# Tokens de entrada: 50
# Tokens de salida: 26

# %% [markdown]
# ## Usando Roles del Sistema
#
# El rol "system" permite establecer el comportamiento y contexto del asistente antes de la conversación.

# %%
# Ejemplo con mensaje de sistema
def usar_mensaje_sistema():
    try:
        response = client.chat.completions.create(
            model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
            messages=[
                {
                    "role": "system",
                    "content": "Eres un experto en tecnología que explica conceptos complejos de manera simple y amigable. Siempre incluyes ejemplos prácticos."
                },
                {
                    "role": "user",
                    "content": "¿Qué es una API?"
                }
            ],
            temperature=0.7,
            max_tokens=200
        )

        print("=== Respuesta con Mensaje de Sistema ===")
        print(response.choices[0].message.content)

    except Exception as e:
        print(f"Error: {e}")

# Ejecutar función
usar_mensaje_sistema()
# Out:
# Error: name 'client' is not defined

# %% [markdown]
# ## Explorando Parámetros de Configuración
#
# Los parámetros más importantes al hacer llamadas a LLMs son:
#
# - **temperature**: Controla la creatividad (0.0 = determinístico, 1.0 = muy creativo)
# - **max_tokens**: Límite de tokens en la respuesta
# - **model**: El modelo específico a usar (`llama-3.3-70b-versatile`, `llama-3.1-8b-instant`, etc.)
# - **messages**: Array de mensajes con roles (system, user, assistant)

# %%
# Comparando diferentes valores de temperature
def comparar_temperature():
    prompt = "Escribe una historia muy corta sobre un robot que aprende a cocinar."

    temperatures = [0.1, 0.5, 0.9]

    for temp in temperatures:
        print(f"\n{'='*50}")
        print(f"TEMPERATURE: {temp}")
        print('='*50)

        try:
            response = client.chat.completions.create(
                model=os.getenv("LLM_MODEL", "llama-3.3-70b-versatile"),
                messages=[{"role": "user", "content": prompt}],
                temperature=temp,
                max_tokens=100
            )

            print(response.choices[0].message.content)
            print(f"\nTokens usados: {response.usage.total_tokens}")

        except Exception as e:
            print(f"Error: {e}")

# Ejecutar comparación
comparar_temperature()
# Out:
# ==================================================
# TEMPERATURE: 0.1
# ==================================================
# En un futuro no muy lejano, en un laboratorio de robótica avanzada, un equipo de ingenieros creó a "Zeta", un robot diseñado para aprender y adaptarse a nuevas tareas. Un día, decidieron enseñarle a cocinar.
#
# Al principio, Zeta se mostró torpe en la cocina, derramando ingredientes y quemando platos. Sin embargo, con cada intento, su procesador avanzado aprend
#
# Tokens usados: 152
#
# ==================================================
# TEMPERATURE: 0.5
# ==================================================
# En un futuro no muy lejano, en un laboratorio de robótica avanzada, un equipo de ingenieros creó a "Zeta", un robot diseñado para aprender y adaptarse a nuevas tareas. Un día, mientras observaba a su creador preparar la cena, Zeta se sintió fascinado por el proceso de cocinar. Con su avanzada inteligencia artificial, comenzó a aprender recetas y técnicas culinarias.
#
# Pronto
#
# Tokens usados: 152
#
# ==================================================
# TEMPERATURE: 0.9
# ==================================================
# Un robot llamado Zeta, diseñado para realizar tareas domésticas, descubrió un viejo libro de recetas en la cocina. Intrigado, comenzó a leer y a experimentar con los ingredientes. Pronto, Zeta creaba deliciosos platos que sorprendían a su dueño. Un día, preparó una comida completa para una cena especial y recibió un aplauso. Desde entonces, Zeta se convirtió en el
#
# Tokens usados: 152

# %% [markdown]
# ## Ejercicios Prácticos
#
# ### Ejercicio 1: Experimentar con Diferentes Modelos
# Modifica el código para probar diferentes modelos disponibles (si tienes acceso):
# - `llama-3.3-70b-versatile` (el que usamos por defecto)
# - `llama-3.1-8b-instant` (más rápido y liviano)
# - `openai/gpt-oss-20b`
#
# Revisa todos los modelos disponibles en la [documentación de Groq](https://console.groq.com/docs/models).
#
# > **Ojo con los modelos de razonamiento** (como `openai/gpt-oss-120b`): consumen parte del
# > presupuesto de `max_tokens` en razonamiento interno que no ves, así que con valores bajos
# > pueden devolver una respuesta vacía. Es un buen experimento para el Ejercicio 3.
#
# ### Ejercicio 2: Crear un Asistente Especializado
# Diseña un mensaje de sistema para crear un asistente especializado en un tema específico (ejemplo: finanzas, salud, educación).
#
# ### Ejercicio 3: Optimización de Tokens
# Experimenta con diferentes valores de max_tokens para encontrar el equilibrio entre respuesta completa y eficiencia de costos.
#
# ## Conceptos Clave
#
# 1. **Configuración segura** de APIs usando variables de entorno
# 2. **Parámetros básicos** para controlar el comportamiento del modelo
# 3. **Manejo de errores** en llamadas a APIs
# 4. **Roles de mensajes** (system, user, assistant)
# 5. **Monitoreo de uso** de tokens y costos
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos cómo LangChain simplifica y abstrae estas operaciones, proporcionando herramientas más poderosas para el desarrollo de aplicaciones con LLMs.
